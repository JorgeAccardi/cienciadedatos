# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeAccardi/cienciadedatos/blob/main/Aus_Inc_GKN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv('IN2-C1a_145.gkn', skiprows=9)

# %%
datos
# Out:
#      FLEVEL      A+      A-      B+      B-
# 0      92.0     455    -450     268    -240
# 1      91.5     503    -496     217    -201
# 2      91.0     536    -527     162    -147
# 3      90.5     564    -559     132    -115
# 4      90.0     585    -580      93     -72
# ..      ...     ...     ...     ...     ...
# 179     2.5    -116     122    -308     332
# 180     2.0    -325     343      25       0
# 181     1.5    -443     450     286    -260
# 182     1.0    -497     500     421    -406
# 183     0.5    -497     499     421    -406
#
# [184 rows x 5 columns]
